# %%
from textblob import TextBlob #for spelling correction
import re #for spelling correction
import string #for punctuation correction
from language_tool_python import LanguageTool #for grammar correction
from tkinter import * #for GUI

# %% [markdown]
# # Spelling Correction Function

# %%
def correct_spelling(sentence):
    # Tokenize the sentence into words
    words = sentence.split()

    corrected_words = []
    for word in words:
        # Preserve the case of the first letter using regular expressions
        if re.match(r'[A-Z]', word):  # Check if the word starts with an uppercase letter
            corrected_word = str(TextBlob(word.lower()).correct()).capitalize()
        else:
            corrected_word = str(TextBlob(word).correct())
        
        corrected_words.append(corrected_word)

    return ' '.join(corrected_words)

# %% [markdown]
# # Punctuation Correction Function

# %%
def correct_punctuation(sentence):
    punctuation_marks = set(string.punctuation) - {"'"}

    corrected_sentence = []
    words = sentence.split()

    for word in words:
        if word[-1] in punctuation_marks:
            if len(word) > 1 and word[-2] not in string.whitespace:
                corrected_sentence.append(word[:-1] + " " + word[-1])
            else:
                corrected_sentence.append(word)
        else:
            corrected_sentence.append(word)

    return ' '.join(corrected_sentence)

# %% [markdown]
# # Grammar Correction Function

# %%
def correct_grammar(sentence):
    tool = LanguageTool('en-US')
    matches = tool.check(sentence)
    return tool.correct(sentence), matches

# %% [markdown]
# # Auto Correct Function

# %%
def auto_correct_with_mistakes(sentence):
    corrected_spelling = correct_spelling(sentence)
    corrected_punctuation = correct_punctuation(corrected_spelling)
    corrected_grammar, grammar_mistakes = correct_grammar(corrected_punctuation)
    mistakes = {
        "Spelling": corrected_spelling != sentence,
        "Punctuation": corrected_punctuation != corrected_spelling,
        "Grammar": grammar_mistakes
    }
    return corrected_grammar, mistakes

# %%
from tkinter import *
from tkinter import filedialog
from docx import Document
import PyPDF2

class main:
    def __init__(self, root):
        self.root = root
        root.geometry("1400x533")
        root.maxsize(1400,533)
        root.minsize(1400,533)
        
        root.title("Auto Correct System")
        
        Header_frame = Frame(root, bg="lavender", height=150)
        title_label = Label(Header_frame, text="   Auto Correct System   ", bg="white",
                            font=('Garuda', 30, 'bold', 'italic'), pady=10)
        
        Center_frame = Frame(root, bg="medium slate blue", height=450)
        
        Center_block1 = Frame(Center_frame, bg="medium slate blue", width=700, height=400)
        uploadfilebut_label = Label(Center_block1, text="Upload File for the Auto Corect", bg="lavender",
                            font=('Garuda', 10, 'bold', 'italic'), justify="left")
        fileupload_button = Button(Center_block1, text="Choose a File", bg="medium sea green", font=('Garuda',10), 
                                   width=12, height=1, fg="white", activebackground="lavender", activeforeground="black",
                                  )
        writetext_label = Label(Center_block1, text="Write text for auto correct:", bg="lavender",
                            font=('Garuda', 10, 'bold', 'italic'), justify="left")
        writetext_Entry = Text(Center_block1, font=('Garuda',10), width=97)
        checktext_button = Button(Center_block1, text="Correct Text",  bg="medium sea green", font=('Garuda',10), 
                                   width=12, height=1, fg="white", activebackground="lavender", activeforeground="black",)
        
        
        Center_block2 = Frame(Center_frame, bg="orchid", width=690, height=400)
        correct_label = Label(Center_block2, text="Aut Corrected Text:", bg="lavender",
                            font=('Garuda', 10, 'bold', 'italic'), justify="left")
        correcttext_label = Label(Center_block2, bg="white", font=('Garuda',10), width=80,height=22, justify="left", 
                                  anchor="nw")
        
        
        def selectFile():
            file_path = filedialog.askopenfilename(initialdir='D://', title="Select File",
                                filetypes=[("Text Files", "*.txt"), ("Word Documents", "*.docx"), ("PDF Files", "*.pdf")])
            if file_path.endswith('.docx'):
                try:
                    doc = Document(file_path)
                    whole_text = ""
                    for paragraph in doc.paragraphs:
                        whole_text += paragraph.text + "\n"
                    print(f"Original Sentence: {whole_text}")
                    Testtext(whole_text)
                except Exception as e:
                    print(f"Error reading the Word document: {e}")
            elif file_path.endswith('.txt'):
                try:
                    with open(file_path, 'r') as file:
                        content = file.read()
                        print(content)
                except Exception as e:
                    print(f"Error reading the text file: {e}")
            elif file_path.endswith('.pdf'):
                try:
                    with open(file_path, 'rb') as file:
                        pdf_reader = PyPDF2.PdfReader(file)
                        num_pages = len(pdf_reader.pages)
                        for page_num in range(num_pages):
                            page = pdf_reader.getPage(page_num)
                            print(page.extract_text())
                except Exception as e:
                    print(f"Error reading the PDF file: {e}")
            else:
                print("Unsupported file format. Please provide a .docx or .txt file.")
                
        def Testtext(data):
            corrected_sentence, mistakes = auto_correct_with_mistakes(data)
            correcttext_label.config(text=corrected_sentence)
            
            print(f"Auto-corrected Sentence: {corrected_sentence} \n")

            print("\nDetected Mistakes:")
            for mistake_type, mistake_detail in mistakes.items():
                if mistake_type == "Grammar":
                    print(f"Grammar Mistakes:")
                    for mistake in mistake_detail:
                        print(f"  - {mistake}")
            else:
                print(f"{mistake_type} mistake: {mistake_detail}")
                
        def gettext():
            sent = writetext_Entry.get("1.0", "end-1c")
            
            Testtext(sent)
        
        fileupload_button['command'] = selectFile
        checktext_button['command'] = gettext
        
        
        
        
        Header_frame.pack(side=TOP, fill=BOTH)
        title_label.pack(pady=15)
        
        Center_frame.pack(side=TOP, fill=BOTH)
        
        Center_block1.pack(side=LEFT, fill=BOTH)
        uploadfilebut_label.pack(side=TOP, pady=(20,0), padx=10, anchor="w")
        fileupload_button.pack(side=TOP, pady=10, padx=10, anchor="w")
        writetext_label.pack(side=TOP, pady=(10,0), padx=10, anchor="w")
        writetext_Entry.pack(side=TOP, padx=10, pady=5, expand=1)
        writetext_Entry.config(height=15)
        checktext_button.pack(side=TOP, pady=15, padx=10, anchor="w")
        
        Center_block2.pack(side=LEFT, fill=BOTH, padx=(10,0))
        correct_label.pack(side=TOP, pady=(20,0), padx=20, anchor="w")
        correcttext_label.pack(side=TOP, padx=20,pady=10)
        correct_label.pack(side=TOP, pady=(20,0), padx=20, anchor="w")
        
root = Tk()
obj = main(root)
mainloop()
# Out:
# Original Sentence: Endorsement Letter for Award
#
#
#
# Dr. Hamayun Khan
#
# Branch Counselor
#
# IEEE Superior University Lahore
#
# +92-334-7213157
#
# Hamayun.khan@superior.edu.pk
#
#
#
# December 10, 2022
#
#
#
# IEEE Lahore Section
#
#
#
# Dear,
#
# My name is Dr. Hamayun Khan and I’m Branch Counselor at IEEE Superior University Lahore Student Branch.  I’m writing to provide official endorsement for IEEE Lahore Section Outstanding Student Branch Award for IEEE Lahore Section AGM Awards 2023. I am working in IEEE Superior University Lahore from last 2 year.
#
#
#
# IEEE Superior University Student Branch had organized 15+ events this year which includes training sessions, seminars, competitions, webinar and conference. IEEE SU had collaborated and participated in different mega events like SOFTEC’23, ENSOFEST’23, PUCON’23 and UET ACM Technical Symposium 3.0.  Students from IEEE Superior University won different awards in external participations. IEEE Superior University had award as an Outstanding Collaborator in ENSOFEST’23 and UET ACM Technical Symposium 3.0. IEEE Superior University always organize different events for the growth and betterment of the students. He also won the grant of 80$ for the event from IEEE SPAx.
#
#
#
# Thank you for taking the time to consider and read the endorsement letter for the IEEE Lahore Student Branch Award. If you need any further information, you can contact me through my email: Hamayun.khan@superior.edu.pk.
#
#
#
# Signature:
#
# Dr. Hamayun Khan
#
#
#
#
# Auto-corrected Sentence: Endorsement Letter for Award Dr. Humayun Khan Branch Counselor Were Superior University Labor +92-334-7213157 Hamayun.khan@superior.ed.pp December 10, 2022, Were Labor Section Dear, My name is Dr. Humayun Khan and I’m Branch Counselor at Were Superior University Labor Student Branch. I’m writing to provide official endorsement for Were Labor Section Outstanding Student Branch Award for Were Labor Section Am Awards 2023. I am working in Were Superior University Labor from last 2 year. Were Superior University Student Branch had organized 15 + events this year which includes training sessions, seminary, competition, Weimar and conference. Were S had collaborated and participated in different meg events like Soften’23, Unsafest’23, Upon’23 and Met Am Technical Symposium 3.0. Students from Were Superior University won different awards in external participation. Were Superior University had award as an Outstanding Collaboration in Unsafest’23 and Met Am Technical Symposium 3.0. Were Superior University always organize different events for the growth and betterment of the students. He also won the grant of $80 for the event from Where Span. Thank you for taking the time to consider and read the endorsement letter for the Were Labor Student Branch Award. If you need any further information, you can contact me through my email : Hamayun.khan@superior.ed.pp. Signature : Dr. Humayun Khan
#
#
# Detected Mistakes:
# Grammar Mistakes:
#   - Offset 31, length 2, Rule ID: COMMA_PARENTHESIS_WHITESPACE
# Message: Don’t put a space before the full stop.
# Suggestion: .
# Endorsement Letter for Award Dr . Hamayun Khan Branch Counselor Were Supe...
#                                ^^
#   - Offset 34, length 7, Rule ID: MORFOLOGIK_RULE_EN_US
# Message: Possible spelling mistake found.
# Suggestion: Humayun
# Endorsement Letter for Award Dr . Hamayun Khan Branch Counselor Were Superior Uni...
#                                   ^^^^^^^
#   - Offset 150, length 2, Rule ID: COMMA_PARENTHESIS_WHITESPACE
# Message: Put a space after the comma, but not before the comma.
# Suggestion: ,
# ... Hamayun.khan@superior.ed.pp December 10 , 2022 Were Labor Section Dear , My name ...
#                                            ^^
#   - Offset 153, length 4, Rule ID: MISSING_COMMA_AFTER_YEAR
# Message: Some style guides suggest that commas should set off the year in a month-day-year date.
# Suggestion: 2022,
# ...mayun.khan@superior.ed.pp December 10 , 2022 Were Labor Section Dear , My name is Dr...
#                                            ^^^^
#   - Offset 181, length 2, Rule ID: COMMA_PARENTHESIS_WHITESPACE
# Message: Put a space after the comma, but not before the comma.
# Suggestion: ,
# ...cember 10 , 2022 Were Labor Section Dear , My name is Dr . Hamayun Khan and I’m Br...
#                                            ^^
#   - Offset 197, length 2, Rule ID: COMMA_PARENTHESIS_WHITESPACE
# Message: Don’t put a space before the full stop.
# Suggestion: .
# ... Were Labor Section Dear , My name is Dr . Hamayun Khan and I’m Branch Counselor a...
#                                            ^^
#   - Offset 200, length 7, Rule ID: MORFOLOGIK_RULE_EN_US
# Message: Possible spelling mistake found.
# Suggestion: Humayun
# ...re Labor Section Dear , My name is Dr . Hamayun Khan and I’m Branch Counselor at Were S...
#                                            ^^^^^^^
#   - Offset 286, length 2, Rule ID: COMMA_PARENTHESIS_WHITESPACE
# Message: Don’t put a space before the full stop.
# Suggestion: .
# ...Superior University Labor Student Branch . I’m writing to provide official endorse...
#                                            ^^
#   - Offset 426, length 2, Rule ID: COMMA_PARENTHESIS_WHITESPACE
# Message: Don’t put a space before the full stop.
# Suggestion: .
# ...rd for Were Labor Section Am Awards 2023 . I am working in Were Superior Universit...
#                                            ^^
#   - Offset 492, length 2, Rule ID: COMMA_PARENTHESIS_WHITESPACE
# Message: Don’t put a space before the full stop.
# Suggestion: .
# ...perior University Labor from last 2 year . Were Superior University Student Branch...
#                                            ^^
#   - Offset 603, length 2, Rule ID: COMMA_PARENTHESIS_WHITESPACE
# Message: Put a space after the comma, but not before the comma.
# Suggestion: ,
# ...is year which includes training sessions , seminary , competition , weimar and con...
#                                            ^^
#   - Offset 614, length 2, Rule ID: COMMA_PARENTHESIS_WHITESPACE
# Message: Put a space after the comma, but not before the comma.
# Suggestion: ,
# ...ch includes training sessions , seminary , competition , weimar and conference . W...
#                                            ^^
#   - Offset 628, length 2, Rule ID: COMMA_PARENTHESIS_WHITESPACE
# Message: Put a space after the comma, but not before the comma.
# Suggestion: ,
# ...aining sessions , seminary , competition , weimar and conference . Were S had coll...
#                                            ^^
#   - Offset 631, length 6, Rule ID: MORFOLOGIK_RULE_EN_US
# Message: Possible spelling mistake found.
# Suggestion: Weimar; Lamar; Samar; Jamar; Wiemar; Tamar; water; war; wear; radar; ear; warmer; Qatar; Rama; Dakar; Jamal; Tatar; gamer; wafer; wager; Hagar; Kama; Saar; Samara; Tamara; Walmart; lama; lamas; mama; Delmar; tamer; wader; waver; caiman; Tamra; mamas; webinar; lamer; weir; Gaiman; Gama; Gamay; Hadar; Haman; Maiman; Paar; WIMAX; samey; Camaro; Dagmar; Hamas; Kamal; Nagar; Namur; Neymar; Samir; Wasmer; Waxman; Weiser; Yanmar
# ...ing sessions , seminary , competition , weimar and conference . Were S had collaborate...
#                                            ^^^^^^
#   - Offset 652, length 2, Rule ID: COMMA_PARENTHESIS_WHITESPACE
# Message: Don’t put a space before the full stop.
# Suggestion: .
# ...ry , competition , weimar and conference . Were S had collaborated and participate...
#                                            ^^
#   - Offset 731, length 1, Rule ID: EN_UNPAIRED_BRACKETS
# Message: Unpaired symbol: ‘‘’ seems to be missing
# ...ated in different meg events like Soften’23 , Ensofest’23 , Upon’23 and Met Am Te...
#                                            ^
#   - Offset 734, length 2, Rule ID: COMMA_PARENTHESIS_WHITESPACE
# Message: Put a space after the comma, but not before the comma.
# Suggestion: ,
# ...d in different meg events like Soften’23 , Ensofest’23 , Upon’23 and Met Am Techni...
#                                            ^^
#   - Offset 737, length 8, Rule ID: MORFOLOGIK_RULE_EN_US
# Message: Possible spelling mistake found.
# Suggestion: Unsafest
# ...n different meg events like Soften’23 , Ensofest’23 , Upon’23 and Met Am Technical Sympo...
#                                            ^^^^^^^^
#   - Offset 745, length 1, Rule ID: EN_UNPAIRED_BRACKETS
# Message: Unpaired symbol: ‘‘’ seems to be missing
# ...ent meg events like Soften’23 , Ensofest’23 , Upon’23 and Met Am Technical Sympos...
#                                            ^
#   - Offset 748, length 2, Rule ID: COMMA_PARENTHESIS_WHITESPACE
# Message: Put a space after the comma, but not before the comma.
# Suggestion: ,
# ... meg events like Soften’23 , Ensofest’23 , Upon’23 and Met Am Technical Symposium ...
#                                            ^^
#   - Offset 755, length 1, Rule ID: EN_UNPAIRED_BRACKETS
# Message: Unpaired symbol: ‘‘’ seems to be missing
# ...ents like Soften’23 , Ensofest’23 , Upon’23 and Met Am Technical Symposium 3.0 . ...
#                                            ^
#   - Offset 793, length 2, Rule ID: COMMA_PARENTHESIS_WHITESPACE
# Message: Don’t put a space before the full stop.
# Suggestion: .
# ...on’23 and Met Am Technical Symposium 3.0 . Students from Were Superior University ...
#                                            ^^
#   - Offset 881, length 2, Rule ID: COMMA_PARENTHESIS_WHITESPACE
# Message: Don’t put a space before the full stop.
# Suggestion: .
# ...fferent awards in external participation . Were Superior University had award as a...
#                                            ^^
#   - Offset 954, length 8, Rule ID: MORFOLOGIK_RULE_EN_US
# Message: Possible spelling mistake found.
# Suggestion: Unsafest
# ...ward as an Outstanding Collaboration in Ensofest’23 and Met Am Technical Symposium 3.0 ....
#                                            ^^^^^^^^
#   - Offset 962, length 1, Rule ID: EN_UNPAIRED_BRACKETS
# Message: Unpaired symbol: ‘‘’ seems to be missing
# ...an Outstanding Collaboration in Ensofest’23 and Met Am Technical Symposium 3.0 . ...
#                                            ^
#   - Offset 1000, length 2, Rule ID: COMMA_PARENTHESIS_WHITESPACE
# Message: Don’t put a space before the full stop.
# Suggestion: .
# ...st’23 and Met Am Technical Symposium 3.0 . Were Superior University always organiz...
#                                            ^^
#   - Offset 1106, length 2, Rule ID: COMMA_PARENTHESIS_WHITESPACE
# Message: Don’t put a space before the full stop.
# Suggestion: .
# ...he growth and betterment of the students . He also won the grant of 80 $ for the e...
#                                            ^^
#   - Offset 1134, length 4, Rule ID: CURRENCY
# Message: The currency mark is usually put at the beginning of the number.
# Suggestion: $80
# ...the students . He also won the grant of 80 $ for the event from Were Span . Thank yo...
#                                            ^^^^
#   - Offset 1158, length 4, Rule ID: WERE_VBB
# Message: Did you mean “where” or “we”?
# Suggestion: Where; We
# ...on the grant of 80 $ for the event from Were Span . Thank you for taking the time to...
#                                            ^^^^
#   - Offset 1167, length 2, Rule ID: COMMA_PARENTHESIS_WHITESPACE
# Message: Don’t put a space before the full stop.
# Suggestion: .
# ...ant of 80 $ for the event from Were Span . Thank you for taking the time to consid...
#                                            ^^
#   - Offset 1283, length 2, Rule ID: COMMA_PARENTHESIS_WHITESPACE
# Message: Don’t put a space before the full stop.
# Suggestion: .
# ... for the Were Labor Student Branch Award . If you need any further information , y...
#                                            ^^
#   - Offset 1321, length 2, Rule ID: COMMA_PARENTHESIS_WHITESPACE
# Message: Put a space after the comma, but not before the comma.
# Suggestion: ,
# ...rd . If you need any further information , you can contact me through my email : H...
#                                            ^^
#   - Offset 1389, length 2, Rule ID: COMMA_PARENTHESIS_WHITESPACE
# Message: Don’t put a space before the full stop.
# Suggestion: .
# ...h my email : Hamayun.khan@superior.ed.pp . Signature : Dr . Hamayun Khan
#                                            ^^
#   - Offset 1406, length 2, Rule ID: COMMA_PARENTHESIS_WHITESPACE
# Message: Don’t put a space before the full stop.
# Suggestion: .
# ...yun.khan@superior.ed.pp . Signature : Dr . Hamayun Khan
#                                            ^^
#   - Offset 1409, length 7, Rule ID: MORFOLOGIK_RULE_EN_US
# Message: Possible spelling mistake found.
# Suggestion: Humayun
# ....khan@superior.ed.pp . Signature : Dr . Hamayun Khan
#                                            ^^^^^^^
# Grammar mistake: [Match({'ruleId': 'COMMA_PARENTHESIS_WHITESPACE', 'message': 'Don’t put a space before the full stop.', 'replacements': ['.'], 'offsetInContext': 31, 'context': 'Endorsement Letter for Award Dr . Hamayun Khan Branch Counselor Were Supe...', 'offset': 31, 'errorLength': 2, 'category': 'TYPOGRAPHY', 'ruleIssueType': 'whitespace', 'sentence': 'Endorsement Letter for Award Dr .'}), Match({'ruleId': 'MORFOLOGIK_RULE_EN_US', 'message': 'Possible spelling mistake found.', 'replacements': ['Humayun'], 'offsetInContext': 34, 'context': 'Endorsement Letter for Award Dr . Hamayun Khan Branch Counselor Were Superior Uni...', 'offset': 34, 'errorLength': 7, 'category': 'TYPOS', 'ruleIssueType': 'misspelling', 'sentence': 'Hamayun Khan Branch Counselor Were Superior University Labor +92-334-7213157 Hamayun.khan@superior.ed.pp December 10 , 2022 Were Labor Section Dear , My name is Dr .'}), Match({'ruleId': 'COMMA_PARENTHESIS_WHITESPACE', 'message': 'Put a space after the comma, but not before the comma.', 'replacements': [','], 'offsetInContext': 43, 'context': '... Hamayun.khan@superior.ed.pp December 10 , 2022 Were Labor Section Dear , My name ...', 'offset': 150, 'errorLength': 2, 'category': 'TYPOGRAPHY', 'ruleIssueType': 'whitespace', 'sentence': 'Hamayun Khan Branch Counselor Were Superior University Labor +92-334-7213157 Hamayun.khan@superior.ed.pp December 10 , 2022 Were Labor Section Dear , My name is Dr .'}), Match({'ruleId': 'MISSING_COMMA_AFTER_YEAR', 'message': 'Some style guides suggest that commas should set off the year in a month-day-year date.', 'replacements': ['2022,'], 'offsetInContext': 43, 'context': '...mayun.khan@superior.ed.pp December 10 , 2022 Were Labor Section Dear , My name is Dr...', 'offset': 153, 'errorLength': 4, 'category': 'AMERICAN_ENGLISH_STYLE', 'ruleIssueType': 'style', 'sentence': 'Hamayun Khan Branch Counselor Were Superior University Labor +92-334-7213157 Hamayun.khan@superior.ed.pp December 10 , 2022 Were Labor Section Dear , My name is Dr .'}), Match({'ruleId': 'COMMA_PARENTHESIS_WHITESPACE', 'message': 'Put a space after the comma, but not before the comma.', 'replacements': [','], 'offsetInContext': 43, 'context': '...cember 10 , 2022 Were Labor Section Dear , My name is Dr . Hamayun Khan and I’m Br...', 'offset': 181, 'errorLength': 2, 'category': 'TYPOGRAPHY', 'ruleIssueType': 'whitespace', 'sentence': 'Hamayun Khan Branch Counselor Were Superior University Labor +92-334-7213157 Hamayun.khan@superior.ed.pp December 10 , 2022 Were Labor Section Dear , My name is Dr .'}), Match({'ruleId': 'COMMA_PARENTHESIS_WHITESPACE', 'message': 'Don’t put a space before the full stop.', 'replacements': ['.'], 'offsetInContext': 43, 'context': '... Were Labor Section Dear , My name is Dr . Hamayun Khan and I’m Branch Counselor a...', 'offset': 197, 'errorLength': 2, 'category': 'TYPOGRAPHY', 'ruleIssueType': 'whitespace', 'sentence': 'Hamayun Khan Branch Counselor Were Superior University Labor +92-334-7213157 Hamayun.khan@superior.ed.pp December 10 , 2022 Were Labor Section Dear , My name is Dr .'}), Match({'ruleId': 'MORFOLOGIK_RULE_EN_US', 'message': 'Possible spelling mistake found.', 'replacements': ['Humayun'], 'offsetInContext': 43, 'context': '...re Labor Section Dear , My name is Dr . Hamayun Khan and I’m Branch Counselor at Were S...', 'offset': 200, 'errorLength': 7, 'category': 'TYPOS', 'ruleIssueType': 'misspelling', 'sentence': "Hamayun Khan and I'm Branch Counselor at Were Superior University Labor Student Branch ."}), Match({'ruleId': 'COMMA_PARENTHESIS_WHITESPACE', 'message': 'Don’t put a space before the full stop.', 'replacements': ['.'], 'offsetInContext': 43, 'context': '...Superior University Labor Student Branch . I’m writing to provide official endorse...', 'offset': 286, 'errorLength': 2, 'category': 'TYPOGRAPHY', 'ruleIssueType': 'whitespace', 'sentence': "Hamayun Khan and I'm Branch Counselor at Were Superior University Labor Student Branch ."}), Match({'ruleId': ' ...
# Auto-corrected Sentence: I am Abdullah Maroon. I live a Parisian. England
#
#
# Detected Mistakes:
# Grammar Mistakes:
#   - Offset 20, length 2, Rule ID: COMMA_PARENTHESIS_WHITESPACE
# Message: Don’t put a space before the full stop.
# Suggestion: .
# I am Abdullah Maroon . I live a Parisian . England
#                     ^^
#   - Offset 40, length 2, Rule ID: COMMA_PARENTHESIS_WHITESPACE
# Message: Don’t put a space before the full stop.
# Suggestion: .
# ...I am Abdullah Maroon . I live a Parisian . England
#                                            ^^
# Grammar mistake: [Match({'ruleId': 'COMMA_PARENTHESIS_WHITESPACE', 'message': 'Don’t put a space before the full stop.', 'replacements': ['.'], 'offsetInContext': 20, 'context': 'I am Abdullah Maroon . I live a Parisian . England', 'offset': 20, 'errorLength': 2, 'category': 'TYPOGRAPHY', 'ruleIssueType': 'whitespace', 'sentence': 'I am Abdullah Maroon .'}), Match({'ruleId': 'COMMA_PARENTHESIS_WHITESPACE', 'message': 'Don’t put a space before the full stop.', 'replacements': ['.'], 'offsetInContext': 43, 'context': '...I am Abdullah Maroon . I live a Parisian . England', 'offset': 40, 'errorLength': 2, 'category': 'TYPOGRAPHY', 'ruleIssueType': 'whitespace', 'sentence': 'I live a Parisian .'})]

# %%
sentence = "Hee wrotes an eemportant meesage. He do not go to school yesterday!"

corrected_sentence, mistakes = auto_correct_with_mistakes(sentence)

print(f"Original Sentence: {sentence}")
print(f"Auto-corrected Sentence: {corrected_sentence}")

print("\nDetected Mistakes:")
for mistake_type, mistake_detail in mistakes.items():
    if mistake_type == "Grammar":
        print(f"Grammar Mistakes:")
        for mistake in mistake_detail:
            print(f"  - {mistake}")
    else:
        print(f"{mistake_type} mistake: {mistake_detail}")
